# %%
import time
import serial

# %%
arduinoData = serial.Serial("com4",115200)
# serial.Serial("/dev/serial/port1", 115200)
time.sleep(1)

# %%
while True:
    time.sleep(0.5)
    print(arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\OMARF~1\AppData\Local\Temp/ipykernel_15668/956827619.py in <module>
#       1 while True:
#       2     time.sleep(0.5)
# ----> 3     print(arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2])
#
# IndexError: list index out of range

# %%
arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]
# Out:
# '94.59,12.95,100.58,0.00\r'

# %%
firstval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')
time.sleep(0.5)
secondval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')
time.sleep(0.5)
thirdval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')

# %%
while True :
    firstval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')
    time.sleep(1)
    secondval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')
    time.sleep(0.5)
    thirdval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')

    a1 = round(float(firstval[0]))
    a2 = round(float(secondval[0]))
    a3 = round(float(thirdval[0]))

    b1 = round(float(firstval[1]))
    b2 = round(float(secondval[1]))
    b3 = round(float(thirdval[1]))

    c1 = round(float(firstval[2]))
    c2 = round(float(secondval[2]))
    c3 = round(float(thirdval[2]))

    d1 = round(float(firstval[3]))
    d2 = round(float(secondval[3]))
    d3 = round(float(thirdval[3]))

    if ((abs(a1-a2)+abs(a1-a3)+abs(a2-a3)<=3)&(abs(b1-b2)+abs(b1-b3)+abs(b2-b3)<=3)&(abs(c1-c2)+abs(c1-c3)+abs(c2-c3)<=3)&(abs(d1-d2)+abs(d1-d3)+abs(d2-d3)<=3)):
        afinal = round((a1+a2+a3)/3)
        bfinal = round((b1+b2+b3)/3)
        cfinal = round((c1+c2+c3)/3)
        dfinal = round((d1+d2+d3)/3)
        print('wide:',121-afinal,'--height:',115-cfinal,'--length:',bfinal,dfinal)
        break
    else:
        print('hoinai')
        time.sleep(0.5)
        pass
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\OMARF~1\AppData\Local\Temp/ipykernel_14452/2712728875.py in <module>
#       2     firstval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')
#       3     time.sleep(1)
# ----> 4     secondval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')
#       5     time.sleep(0.5)
#       6     thirdval = (arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]).split(',')
#
# IndexError: list index out of range

# %%
a1 = round(float(firstval[0]))
a2 = round(float(secondval[0]))
a3 = round(float(thirdval[0]))

b1 = round(float(firstval[1]))
b2 = round(float(secondval[1]))
b3 = round(float(thirdval[1]))

c1 = round(float(firstval[2]))
c2 = round(float(secondval[2]))
c3 = round(float(thirdval[2]))

d1 = round(float(firstval[3]))
d2 = round(float(secondval[3]))
d3 = round(float(thirdval[3]))

if ((abs(a1-a2)+abs(a1-a3)+abs(a2-a3)<=3)&(abs(b1-b2)+abs(b1-b3)+abs(b2-b3)<=3)&(abs(c1-c2)+abs(c1-c3)+abs(c2-c3)<=3)&(abs(d1-d2)+abs(d1-d3)+abs(d2-d3)<=3)):
    print('halaluiya')
    afinal = round((a1+a2+a3)/3)
    bfinal = round((b1+b2+b3)/3)
    cfinal = round((c1+c2+c3)/3)
    dfinal = round((d1+d2+d3)/3)
    print(afinal,bfinal,cfinal,dfinal)
else:
    print('hoinai')
# Out:
# halaluiya
# 95 13 100 0

# %%
firstval,secondval,thirdval,d1,
# Out:
# (['94.71', '12.94', '100.19', '0.00\r'],
#  ['94.69', '13.06', '100.17', '0.00\r'],
#  ['94.61', '12.95', '100.57', '0.00\r'],
#  0)

# %%
a = [1,2,3,4]
b = [2,3,4,5]
a-b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\OMARF~1\AppData\Local\Temp/ipykernel_6304/1893797164.py in <module>
#       1 a = [1,2,3,4]
#       2 b = [2,3,4,5]
# ----> 3 a-b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
i = 1
def checker():
        
    while True:
        a=10
        if i == 1:
            print('returning')
            return(i,a)
        else:
            print('passing')
            time.sleep(1)
            pass

# %%
a,b = checker()
print(a,b)
# Out:
# returning
# 1 10

# %%
j = 0
while j<10:
    while(arduinoData.inWaiting()==0):
        print("pass")
        pass
    dataPacket = arduinoData.readline()
    print(dataPacket)
    j = j+1
    print(j)
# Out:
# b'1halaluiya\r\n'
# 1
# b'2halaluiya\r\n'
# 2
# b'3halaluiya\r\n'
# 3
# b'4halaluiya\r\n'
# 4
# b'5halaluiya\r\n'
# 5
# b'6halaluiya\r\n'
# 6
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# ...

# %%
arduinoData.flushInput() 
arduinoData.readline()
# Out:
# b'-0.17\r\n'

# %%
buffer_string = ''
buffer_string = buffer_string + str(arduinoData.read(arduinoData.inWaiting())).split()
lines = buffer_string.split('\n') # Guaranteed to have at least 2 entries
last_received = lines[-1]
last_received
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\OMARF~1\AppData\Local\Temp/ipykernel_13940/1519237376.py in <module>
#       1 buffer_string = ''
# ----> 2 buffer_string = buffer_string + str(arduinoData.read(arduinoData.inWaiting())).split()
#       3 lines = buffer_string.split('\n') # Guaranteed to have at least 2 entries
#       4 last_received = lines[-1]
#       5 last_received
#
# TypeError: can only concatenate str (not "list") to str

# %%
arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\OMARF~1\AppData\Local\Temp/ipykernel_13940/2632662436.py in <module>
# ----> 1 arduinoData.read(arduinoData.inWaiting()).decode("utf-8").split("\n")[-2]
#
# IndexError: list index out of range

# %%
arduinoData.flushInput()

# %%
def receiving(arduinoData):
    global last_received

    buffer_string = ''
    while True:
        buffer_string = buffer_string + arduinoData.read(arduinoData.inWaiting())
        if '\n' in buffer_string:
            lines = buffer_string.split('\n') # Guaranteed to have at least 2 entries
            last_received = lines[-2]
            #If the Arduino sends lots of empty lines, you'll lose the
            #last filled line, so you could make the above statement conditional
            #like so: if lines[-2]: last_received = lines[-2]
            buffer_string = lines[-1]
            print(last_received)
        print("noo")

# %%
last_received
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\OMARF~1\AppData\Local\Temp/ipykernel_7428/1610243955.py in <module>
# ----> 1 last_received
#
# NameError: name 'last_received' is not defined

# %%
'''
#define max_distance 200
#include <HX711_ADC.h>

HX711_ADC LoadCell(4, 5); // dt pin, sck pin



const int HtrigPin = 6;
const int HechoPin = 7;

const int LtrigPin = 8;
const int LechoPin = 9;

const int WtrigPin = 10;
const int WechoPin = 11;

long durationH;
long durationL;
long durationW;

float weight;
float height;
float length;
float width; 
//int speakerPin = 12;
void setup() 
{  
  LoadCell.begin();
  LoadCell.start(1000);
  LoadCell.setCalFactor(375);

  pinMode(HtrigPin, OUTPUT);
  pinMode(HechoPin, INPUT);
  pinMode(LtrigPin, OUTPUT);
  pinMode(LechoPin, INPUT);
  pinMode(WtrigPin, OUTPUT);
  pinMode(WechoPin, INPUT);
  Serial.begin(115200);
  delay(500);
}

void loop() 
{ //////////////////////////////////Load Cell////////////////////////////////////////////
  LoadCell.update();
  weight = LoadCell.getData();


  ///////////////////////////////// Height///////////////////////////////////////////////
  // Write a pulse to the HC-SR04 Trigger Pin
  digitalWrite(HtrigPin, LOW);
  delayMicroseconds(2);
  digitalWrite(HtrigPin, HIGH);
  delayMicroseconds(10);
  digitalWrite(HtrigPin, LOW);
  // Measure the response from the HC-SR04 Echo Pin
  durationH = pulseIn(HechoPin, HIGH);
  // Determine distance from duration
  // Use 343 metres per second as speed of sound
  height=(durationH*0.033/2);
  // Prints "Distance: <value>" on the first line of the LCD
  //////////////////////////////////Length/////////////////////////////////////////////////
  digitalWrite(LtrigPin, LOW);
  delayMicroseconds(2);
  digitalWrite(LtrigPin, HIGH);
  delayMicroseconds(10);
  digitalWrite(LtrigPin, LOW);
  durationL = pulseIn(LechoPin, HIGH);
  length=(durationL*0.034/2);
  //////////////////////////////////Width/////////////////////////////////////////////////
  digitalWrite(WtrigPin, LOW);
  delayMicroseconds(2);
  digitalWrite(WtrigPin, HIGH);
  delayMicroseconds(10);
  digitalWrite(WtrigPin, LOW);
  durationW = pulseIn(WechoPin, HIGH);
  width = (durationW*0.034/2);
Serial.print(width);
Serial.print(",");
Serial.print(length);
Serial.print(",");
Serial.print(height);
Serial.print(",");
Serial.println(weight);

delay(450);




}




'''
